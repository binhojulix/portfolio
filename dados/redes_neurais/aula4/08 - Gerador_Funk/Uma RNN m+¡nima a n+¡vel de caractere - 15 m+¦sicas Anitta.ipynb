# %% [markdown]
# # Uma RNN mínima a nível de caractere
#
# Vinicius F. Caridá
#
# Neste notebook nós treinamos uma RNN em algumas músicas da Anitta. Esta RNN que gera um caractere por vez, com base nos caracteres anteriores da sequência.
#
# O código original da RNN foi escrit0 por Andrej Karpathy (atualmente diretor de IA da Tesla Motors).
# O código foi modificado por Peterson Zilli para atender por um número máximo de iterações e ler caracteres utf-8.
#
# Usamos esta RNN para gerar funk a partir do treinamento com as 15 músicas mais acessadas da Anitta que retiramos do site [letras.com.br](www.letras.com.br).
#
# As letras estão no arquivo 'anitta.txt'

# %%
with open('anitta_15.txt', 'r', encoding='utf-8') as txt:
    print(txt.read(500))
# Out:
# Você prepara, mas não dispara
# Você repara, mas não encara
# Se acha o cara, mas não me para
# Tá cheio de maldade, mas não me encara
#
# Você já tá querendo e eu também
# Mas é cheio de história e de porém
# Virou covarde, tô com vontade
# Mas você tá demorando uma eternidade
#
# Se você não vem, eu vou botar pressão
# Não vou te esperar, tô cheia de opção
# Eu não sou mulher de aturar sermão
# Me encara, se prepara
# Que eu vou jogar bem na sua cara
#
# Bem na sua cara
# Eu vou rebolar bem na sua cara
# Bem na sua cara
# Hoje

# %% [markdown]
# Agora, usamos este texto para treinar a rede recorrente

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License

Adapted for python 3.5 by Peterson Katagiri Zilli @petersonzilli
"""

num_iters_max = 100000


import numpy as np

# data I/O
data = open('anitta_15.txt', 'r', encoding='utf-8').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(('data has %d characters, %d unique.' % (data_size, vocab_size)).encode("utf-8"))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 256 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 0.01

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

#while True:
while n < num_iters_max:    
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 1000 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ('------------------------------------------------------------\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 1000 == 0: print ('iter %d, loss: %f\n\n' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# b'data has 17183 characters, 70 unique.'
# ------------------------------------------------------------
#  p(-oRwÀLnxzóMOglàBo ó!.SzFtM!kNaFçéOãk"ÉÀá,wlhn,dNcôcFFÉxk,OtiT
# JsmUErvÔHcÀhêp!eqrÀgdôBk
# eófSv:ntQôCH")s.!xnrEhzILfTçcoIe.-RiQ,aqôak(p(qe nvrtqlÔicÔPxatljãnmêSwbeô"xdIMC!rómiháBçg!Aj?dçd.çAc zôA gsEmR
# ----
# iter 0, loss: 106.212381
#
#
# ------------------------------------------------------------
#   o cenêro,
# Vãican,
# E t cêlgeitsao senar
# Do oras nóendusnaa,
# ADdneo de, bemalorsadejash J ter roqtedonmoito
# Bu camidarsstrindeçlso
# ,u cormsvodo
# Po poi ar pclsor erohané jaip ede oohaceroPa, O muça ho s
# ----
# iter 1000, loss: 80.440126
#
#
# ------------------------------------------------------------
#  bel, dam tate são que aih
# Nhos
# Ion veu mhsra
# Ae tagora peidcaim feCcr,para:sÉu bão ca zdo queze lacçrn
# Beisso euando mem ua viminte mifomer
# Pue vomam
#
# Seibore
# Der rejo quesbora xár boio
# Eeloco me  ult
# ----
# iter 2000, loss: 64.740350
#
#
# ------------------------------------------------------------
#  psaa na meisa?
# H eucondo Soleu ishalraT
# Dumana
# S teuà sina becêt, ne (am lamar
# Npo vosla a vinje, eiide claza darQ
# Eeconto
# E desh
# Uesa can
#
# Teita l most oile touita rualo pama a pavacê
# Obido aamsnh, r
# ----
# iter 3000, loss: 57.185879
#
#
# ------------------------------------------------------------
#  mmida, nhous dei não uão danto
# Der tar
# Vocêm que lozldi
# Ptô a gão
# Eu tihe te tuisvorrim úil dá sinxa vonê facos ravorê poa vom, ntia temi na ou quem mu eu lei velte em missivacê
# Jo cao tozo sca muppaj
# ----
# iter 4000, loss: 53.104778
#
#
# ------------------------------------------------------------
#   é sais vonha ercora
# E deso se cossa, fejha quenpo an star aual meme a cenlandi alo eu doshaimade oibogar pora
# Eu vos au thinna emdo, ou doisço de dagerpare a sino não a
# Mem cempore dessa caicaim
# Tera
# ----
# iter 5000, loss: 50.587302
#
#
# ------------------------------------------------------------
#  ue dhiira de paveu dão
#
# Aó pe tar
# Não fudo que euhorh
# O de Ae ari
#
# Er àá eu oe feuctrar
#
# Voé éuissam indabor
# Vemder Phom pradazud
# QsanBro àars, dande mol uaisenas
# Vor, u nhouca
# MeA to come tra
# Cão bem
# ----
# iter 6000, loss: 48.923944
#
#
# ------------------------------------------------------------
#   elharar
# Eu quem nhadiça quebsnão
# Se da dia
# De que eu subucrr
# Vuis, se de jecar invasçar
# Não po vosêt, à mer coro mino ensasda
# Sa que
# Nsos montó meu não tinheçan
# Eu minturo
# Caixo pascazar
# Phar que tão
# ----
# iter 7000, loss: 47.812847
#
#
# ------------------------------------------------------------
#  ogar
# Dais
# Seranão
# Aão vem tuar
# Mas vom tantoda, eu veu thaber
#
# Se feco te tea ceução adite tançare
# E saz não mo pem dora mensa
#
# Hhém lóraprida é bocvra daqlola, loda ta dosvem tão censais
# Quem noalãe
# ----
# iter 8000, loss: 46.703204
#
#
# ------------------------------------------------------------
#  cofado você
# E essascara é pungar de var cem do arco eu svimand
#
# Eujo ou ta, nor nantharap e qua nhonta dido vez vadijolare am vmu vei radece dococpesansa
# Eu não so tep(o que é que me terisna mempnde o
# ----
# iter 9000, loss: 45.493830
#
#
# ------------------------------------------------------------
#   poucando dem
# Se tele terta:
# Voi ta bes
# Mara e em fiza élita
# Quenavar
# Que belagmina de ocê fasocando lojer
# Jão vem nãe pemprraé quire ansas arm do mina vich, nhabedo
# Miscar, nque curacor
# Parpera é asf
# ----
# iter 10000, loss: 44.886656
#
#
# ------------------------------------------------------------
#
# Pora sa pradogende hatis
# Deixa vacin
# Hebelo, sua vastexa eu thader
# Não pevapal:,
# Me sam
# Eu da assar, er menhonto suezé de e var uçação
#
# Tuê é iw fazes
# Massvoche evar vocição bucana que eu vô minta ça
# ----
# iter 11000, loss: 43.827189
#
#
# ------------------------------------------------------------
#   mer
#
# Eu voqleratgo me so vidade, ses tera, im gocan
# Por da trortr
# Vana de euvam ne sia
# Ei a é vou çó promera
#
# Anvom
# Sege dentar
#
# Sua e eis ne shacai que jogari
# Be caveu té leu!, ea meia
# Mem ne eusos
# ----
# iter 12000, loss: 43.475834
#
#
# ------------------------------------------------------------
#  Bque asper tabit migoradeser lação
#
# Peparo or oladar
# U? muo mão bom mrido
#
# Uto a vor
# Subom
# E aá mibo temo quijo meuií
# Máçenboxarala
#
# Deis Veca po prazer
# Que em bocê
# Se vac vabei
# E peise degothem o com
# ----
# iter 13000, loss: 42.000579
#
#
# ------------------------------------------------------------
#  ida
# Relaa e seitr
# To arosto abelo
#
# fiha u mer
#
# Você
# , sindido
# Pradai
#
# Egêpprmai te lavem frere
# á pmo terar
#
# Nanvo pog, teber
# Deu aprodor mala
# Lrpaha gara
#
# Elaça lo quer sento, cobteçe na deivan o que
# ----
# iter 14000, loss: 41.841601
#
#
# ------------------------------------------------------------
#  im, lotca, me fuvar babçem lhouco
# Quê per ca meu cinta, os ber-sss bro que é cem es o vam
#
# Hoc meu vem pesovar ossa voi que
# Mis bizyr e é não dei
# Aó de pliuque, Caveilficom dinhaido prapasçor de mena
# ----
# iter 15000, loss: 40.802501
#
#
# ------------------------------------------------------------
#  ta nhdia
#
# ão bem fiz ado camaçpro, donvocar
# Mão não me em eustp ader ole co terle er ago é viu preuosanda, anbosem inagas aumina que lali?v
# Deixa ele de voli
#
# Tá budo aifar begjocandiro ade me jelela
#
# ----
# iter 16000, loss: 40.066020
#
#
# ------------------------------------------------------------
#
#
# Hcdejesas que nhais!
# Dencangancar di gemante pondepodo te daporanção aá caração
#
# Sá que nvocê
#
# Panda ilque
#
# Não te se alvic
#
# TumÀo caxu olação
# Aà esé isar a de deveca
# Te em ou cão pem bela
#
# Sa me se
# ----
# iter 17000, loss: 39.129606
#
#
# ------------------------------------------------------------
#  uh, uh, uh
#
# E colinda deu não querere oco ponsou pramiha
# Ho que tina volidé
# Quá eu ssbim, lugra meijando o sais
# Banão vé Praser divou jaz soisa anmr
#
# Parpraisquinão mão
# Oita é tontão me tameudo
# So des
# ----
# iter 18000, loss: 38.819169
#
#
# ------------------------------------------------------------
#  ela cira aibar
# Se mcorte beixo do nassar
# Vêim, qua lua feina é e co ta maqui?
# Dó bente bea te lais que eu doutra
# A vintir, emei cente shom cara boqfem dabo mouha
# Sote do asmintado
# Beu vice é mei ficre
# ----
# iter 19000, loss: 38.030439
#
#
# ------------------------------------------------------------
#  tra
# Quas qua deiventrodam meu mo sei te tem na cuata
# Smi a beradra
# E sam so meu teras a sim
#
# á quer cas a sando e meu me a mea care vei se om? me derorquer peuvtido pra ssh ra sue carar
# Amanto beban
#
# ----
# iter 20000, loss: 37.277102
#
#
# ------------------------------------------------------------
#    osar que tó do mai quese arena é manhonto sum de tendevoca
# Fos a imur
# Neu teganto
# Nando amíseu são centão
# Quando não tunt da canta
# Jo, a que suar
#
# Alis, eltonh
# Diinprodoa quiça a lisa, levou pde era
# ----
# iter 21000, loss: 36.701229
#
#
# ------------------------------------------------------------
#  r Àe fãorra pra me emanderepoá e sa inteu
# Vai eu merarar
# Fa mia que entare data zanço babec
# Dar ar arero
# Facar pa deigore te seu conção
#
# Quenao sou focor turo a amiidado que made var (ão que do vira
# ?
# ----
# iter 22000, loss: 35.903421
#
#
# ------------------------------------------------------------
#  é facar
# Rei pe omiça Você me paa pras
# É em eu ano filao pe crmai
#
# Ei não asuo tuam nua de mem
# Per a olom, me assrança
# Eusto do, coraço carra, rocta tiso
# E amiçande em meu bebom
# Qua vai
# ão de de ara
# ----
# iter 23000, loss: 35.847868
#
#
# ------------------------------------------------------------
#   im iimever não te porlim
# Jóronque volte poda
# Tudia
#
# Ta vei fem noste mem quer quelessom asto ves te meladaz rintão eu vou o bácar e cendader
# Eu smolzro lubte cám traçar
# à éepossoinh uhter
#
# Seg imojhe
# ----
# iter 24000, loss: 34.427337
#
#
# ------------------------------------------------------------
#   você
#
# Ontão dade, iga der u dia
#
# A que vecê
#
# E são tou fiz
# Ja daam
# Deixa ale fanção
#
# Deixquelo e o volpras
# eu quere dide linvar fazer
#
# Sepra se feilo quero ele car,
# Eu sem
# Tiro arsor (ê cê
# A: de per
# ----
# iter 25000, loss: 34.557597
#
#
# ------------------------------------------------------------
#
# E de fazer
# E quissu canter
# Tera que parir def iasevar Dinhabidabbedodida mino é to seu contando
# !rsa é vobado
# Mes e vom laa canmin
# Qãar
# Laspadolou dojer e chalo am emalé
#
# Então
# Cho vou são vaintão
# Me
# ----
# iter 26000, loss: 33.481613
#
#
# ------------------------------------------------------------
#  u ca oua lenho
# Cho ai a elium m boco
# Aisaa bola do bom é ndais
# SQuendo euatconar
#
# Tobem tixo er
# Mam nhasu, não veu er omisso teum mó eu fimalis
# Bem meio é vou tãra
# Eó dou molham e euco eu fugo que eu
# ----
# iter 27000, loss: 33.019647
# ------------------------------------------------------------
#  bou, ra daise
#
# E fão tô que da melia e beiper naro a mum
# Der a vovil, nlovivar eu ssquile nasso cemeção
# En a senlerad:, a a lia
#
# E falo sei é me fazer o bol,
# SBem talá que davir ala a bem
# Par ar mei a
# ----
# iter 28000, loss: 32.242330
#
#
# ------------------------------------------------------------
#  ela quer faiso a galutó
# Ele batga pra tea
#
# Elho te você
# , rou
# Ess o amis, elas bugobad
# Eu fima su você
#
# Boi só fai su mela camiçar, ele lua cemjosade fuco degar, mom uvtin
#
#
# Cov, pela má ra doper
#
# Ee
# ----
# iter 29000, loss: 32.050003
#
#
# ------------------------------------------------------------
#   mindo e fácai faz iã) nto
# Ais o ate velção
# Eu gonta, tia, luecasenfado, bei
# Mão beladir
# Quando nhor?
# Vei per
# Uas ue jeganan sabai
# Per em fico :in
# Condem: comto nas vabae fucom o que ponde mó cêndofaz
# ----
# iter 30000, loss: 31.451168
#
#
# ------------------------------------------------------------
#  m no suatzado que eu sio ela comepazbàr o sento em queré de meleDar
# .is gantereo a divo prraim megono que quera o timg
# Deixa elesssrorerando o tento pruvocando do ma tecarliãa sema o peiser mar iu dau
# ----
# iter 31000, loss: 30.886999
#
#
# ------------------------------------------------------------
#  e eme osto nosso ado arua
# Só alho ao melado
# Nestana só der
# Corer gossa disha lous
# Quende faca
# Des co étinquenando do mei
# CEnter
# Seratar boca que tado tadepradiat!
# Eu fágos becê!r
# Ser cança prlidade de
# ----
# iter 32000, loss: 30.291354
#
#
# ------------------------------------------------------------
#  eitra menha, e bepro meu maso a seumcoate de belem, Eu não quere cantinquer
# Te delhorar (fimim
# Deixo do tumro eg am liatradesando es souto queme eu ma derum
# Fhe e jeu não de parçor!dapme natera
#
# Ponto
# ----
# iter 33000, loss: 29.683763
#
#
# ------------------------------------------------------------
#   mes a derh
# Bem paiso, centare
# Parda
# Ter valela
#
# á a éla nho ar
# Perdom satNço aderana me lepar
# Mos quejo de nassrrrira omenassu dmam
#
# Ai anaixo tão, contaso de nhara, não querona na munho cema que sen
# ----
# iter 34000, loss: 29.828879
#
#
# ------------------------------------------------------------
#  vich, eisó , locê, ela pradar
# Em fize je tado o tur não me êa
# Itrde tem queçar voca do teuda
# E de, iê Muc ela delesa
#
# Eúsapre
# Tó no boca
#
# ê ela
# E fezar arowcera quendo que bocêe e fuJk fazol o eu ?Coí
# ----
# iter 35000, loss: 28.481309
#
#
# ------------------------------------------------------------
#
# Ue de isé sem
# Bel a vem, cuare antande caminha josta mAnho, fait, pro pei
# Alina é poma:
# Vem vor você quen a vale)
#
# Deinho
# Elte quer beijo isso cera
#
# Enqua em seu car ala
# A eu quere vir essilo pra em
# ----
# iter 36000, loss: 29.022323
#
#
# ------------------------------------------------------------
#  issa pra bela
#
# Eu voO cere outla, is!o care vencar
#
# Tene Cerxenme por em deix reltada
# Nessa melsa mento degur
# Der pangamcanção
#
# Vei jão
# Mgo ceijapra artir
# É amprasmoAso faz
# A me parevicara Bep
# : dos o
# ----
# iter 37000, loss: 27.826525
#
#
# ------------------------------------------------------------
#   val atida nta
# Terela so com, me im inhízelhar eu bô entenar
# Dei peraro
#
# O var e agur
# Der as ancá um nima
# Nur a gunta Sei concor po terra
# Bim ua smeulha qua e pro tiapo pende me enlincara
#
# Pua me cerr
# ----
# iter 38000, loss: 27.733405
#
#
# ------------------------------------------------------------
#  e
# Já mou e coreuti
#
# Àisa e louca
# Elasó je siila, mis ail,ges
#
# De vatEí mendo, elte feite ndogvecar pae em mentade de xo enêoje
#
# So te teu reutente paisteader e peisavgiro possa srpraçan!Não te temçand
# ----
# iter 39000, loss: 26.856357
#
#
# ------------------------------------------------------------
#   levar
# Poca tade velisé o conte exa lida delem não meu pongoladerar o quejei que te beiter de mim
# Eu ta soucir
# Que decar
# Deixa era coraf pais aade, mes quera as outih
# Demejo, qualeu quem tum s er euu
# ----
# iter 40000, loss: 26.861211
#
#
# ------------------------------------------------------------
#  o se ferara fiz e nouná bem
# Te ea Sou corta
# A fapa sar Jeus éu jogucando má
# Ahque da minata
# Pado, enfepronco parade pra mam
# Ele quero passim
# Rem quetase, pezsro que mó vocte você
#
# Fuc A osseu var vim
# ----
# iter 41000, loss: 26.306033
#
#
# ------------------------------------------------------------
#  u tuzid
# Ao queli éro nabenter
# Eu di quanto doui faistãodasa sua saró tia me prrzesfaz idianar eu ssio ee vicê
# Mho uh, uharinão
# Tum pmido do dis)o
# Eu não vom je elatiradisa a minha Compara
# Vem sar louc
# ----
# iter 42000, loss: 26.076826
#
#
# ------------------------------------------------------------
#  a quinto pre ondese
#
# Pre anhara, luz me uchere ater
#
# Chaze re quejou tes dentar
#
# Ele é porso meia
# Tmio a maro ar poltádiou gento nessotado que eu diz qua ao quera deija de vinNa belada, sentão assa
#
#
# ----
# iter 43000, loss: 25.496493
#
#
# ------------------------------------------------------------
#  lharatão
# Te sabei pra ma mer darprado vá tia cemeu, tra me ver jaim vel em tero que eu jo quero eu prodorem
# E levar do taro, ão te fecalana, Vogê mai peis adcanto
# Você E éimo se favalha
# NEs a miva te
# ----
# iter 44000, loss: 25.039915
#
#
# ------------------------------------------------------------
#  ntode eca, isa é pontem
# Atcos e canção
#
# O hem osbe ancorazar
#
# u venor
# Doncara
# Agursem vocrovinar
# Alessor
# Quendo ele verar pra só doa cira
#
# Cque essonto
# Não nde padavoi, boiê dingora
#
# Pea em fizer o qu
# ----
# iter 45000, loss: 25.362041
#
#
# ------------------------------------------------------------
#  a do vecê
# , não me ém nago com hóiçoVabpe
# Porajo tavai que aga meiçhrr
# Qua dao tão cemtrai
# Peia, so pera pem ou só dimeras
# Eu osso não veu fãi , bem
# có je "ivariiA
# Não co aÉpros de tladcabrão nhaguca
#
# ----
# iter 46000, loss: 24.262221
#
#
# ------------------------------------------------------------
#  ls er rade ficoi asser
# Te tade oma luma
#
# Te dilo ei fóios de com as faito pora mando
# Pom você
#
# Pra olavare asmo cara, me salo
# Eu co pro em socer dera, dosso prele?, que dançandoale, mentrmirte me onca
# ----
# iter 47000, loss: 25.014610
#
#
# ------------------------------------------------------------
#  ança o ispeisor, sua é me emstarlevar
#
# E depei ar osem misó do com ola seurhola
# Nare de devocar
# Você!
# Quenta mrda a ginte lóvor e meivar não atitlada
# Ner ao ssoabcinaro"a daro que eu tá beuetra missa
# ----
# iter 48000, loss: 23.957326
#
#
# ------------------------------------------------------------
#  i arde ara vele oparou
#
# Enda nande pra misa, elo code ver, ruam deacar vou que so sem vobê varar sasso
# Mnho daixh que eu gosto doscim, babomei a udo,tis
#
# Euhde Ohhe ou pre que, pei beite de vivar, mui
# ----
# iter 49000, loss: 24.240814
#
#
# ------------------------------------------------------------
#  e, iê jê Iê cêricandede é vontenção
# QUando quele à vov e delpacar
# Sue eu euslo que múnacradis erúeizer dege a vilu tenÉ é oúsimádiques quero é poisanto pasmim
# É sangabaca
# Já a meisé senção
# Nnoi veilho
# ----
# iter 50000, loss: 23.218528
#
#
# ------------------------------------------------------------
#  elLantndrdocem gontavilca, tis éu fazer sabolada fizer ber gassporar), is quirpque os miua Eu tô com, nadera
#
# E tra mó im gintuô cueparprassoa Cortendo émtentemporacha eu veg ne so leu tão memi
# O tepr
# ----
# iter 51000, loss: 23.556514
#
#
# ------------------------------------------------------------
#   adianta mou tão
# Mts o que tovelia
# Múixprela, bem
# Me aminvochr, hhho a, iê beboi cer oatão, ela quer e toão
# Sê ben?ão agondo ar tanasseochÀ s badati, ésso sebat
# Cora
# Aá que a ertra
# Você queje por bocê
# ----
# iter 52000, loss: 22.942532
#
#
# ------------------------------------------------------------
#  go vochemacVez de empriat alhhor
# Deixa ele sovei a somação
#
# ô contendodade a uino vim rar re vque ntado a meu tegonto
# Que eu vamino do miis
# Não por ciatão
#
# Nao taipsaz nomol ar elias
# Cordenando
# E puis
# ----
# iter 53000, loss: 23.062194
#
#
# ------------------------------------------------------------
#  o te te deixa em ver, não par bim (ucidpadso
# Exe quilo quer saix
# Elação
# Masta meisa, er focê pinão é elazer que tecado
# Pora du ghacar
#
# Te emora o te vames o que eu fico se elO cameu, eu fapossfaim
# E f
# ----
# iter 54000, loss: 22.369496
#
#
# ------------------------------------------------------------
#  Se a lome, no bocande par não me para
# Mimho assa
#
# Chema ataro ndaim
#
# Nasba olze
#
# Timboso que sabocar
# Cão, você quesorque dei hora
# Você ma ouc?
# Depela que sodoasa
#
# Eu peiseranção de alr
# Far o que denas
# ----
# iter 55000, loss: 22.087059
# ------------------------------------------------------------
#  louqueçar
# Ne bodá em ssor
# Duo asinte de pra, passs:
# Não se allendr mos que so amondo, rocê, eu veu teme arasso, coracordilo
# Mem nem saque me pansanto
# Eu de vim assprrdade eu tô que vam vim filo quer,
# ----
# iter 56000, loss: 22.511050
#
#
# ------------------------------------------------------------
#  pado attevim assido co vomaror
# O aques baijo Com vou pre elen emfina :Énto
# ASzer eu aô bre amlolar
# Me centosso deu
# Pãa elemer que eu quero
# Me do nté tar
# Bem na suampradazaQ
# ende pravola
#
# Eu feçe jo mi
# ----
# iter 57000, loss: 21.620568
#
#
# ------------------------------------------------------------
#  de m tar de praçar
# Eu sebecar bas vachras
# Vebêco
# Meli que do pir
# Dostro comer dis minher
#
# Eu amor
#
# Em no qua do coreçto
# Nossade, canção
# Quarona sá piter:
# Josso jeste, losta arlia, eu quito
# Esse lada m
# ----
# iter 58000, loss: 22.503211
#
#
# ------------------------------------------------------------
#  a ele shora
# De seu cimano deser
#
# Tissa docca der tate leatjão ssim
# Elonque om reitars
# Me tá mase es eu tôubada
#
# Chewa aveche, tin: vaze é belho qua a polta
# A devacha
# Poado a atô
# Te leu que tánto
# Que t
# ----
# iter 59000, loss: 21.380970
#
#
# ------------------------------------------------------------
#  r: Bom dia quir fait)
# Co
# Eu se e emssisar
# Atrostado quevom der eladsa atr
# Fes o quer que quendo caração
# Não a éurar
#
# Pentoradasa hais, não
# Ela deis ascir
# Masena bua jo perpadsade perdar deime ela cora
# ----
# iter 60000, loss: 21.705887
#
#
# ------------------------------------------------------------
#   loucalar
#
# Euda oulum, cê Ihagundo, me vei que nura , sinha e fair
# Dordado ando, emlo pra meiê?
# O., ou a sonte começo que te mais
# Mentero que eu quemi e ammisé, na nhase aga mem cera
#
# Eu vic-r pra ped
# ----
# iter 61000, loss: 20.876005
#
#
# ------------------------------------------------------------
#  quer feito do que tumim
# Se elu vei tepar báctrao sum é conta escara
# Deinha lisaé le vaite pro tia nãom
# Hopar pou fala, cinharepara per passuis
#
# Deixa eisoó , asofaita
# Olha
# E eu fico vim anmeura
# Vai be
# ----
# iter 62000, loss: 21.115816
#
#
# ------------------------------------------------------------
#   gantanda
# Ago veiê, antar
#
# Penção a misa
# É doco quelte que teme coro
# Ha, focabatfiz!
# Qua do, cê
# Nho era a bem
# Eu de falei quemosoa eseluo a mincaro
# Praz na cur, ligar
# Peido vou jo tidar
# Ltudpor de ve
# ----
# iter 63000, loss: 20.656520
#
#
# ------------------------------------------------------------
#   você .dir prosassa itação a meijo quejo dasmio
# Et anz de émplaco
#
# É aolía cintorider: ão sou de gale
# Ho, fei é bobre dobeixe deima pra ma deresa, cema eu tão cumprache, tão sou cinçar
#
# Feca que nhosC
# ----
# iter 64000, loss: 20.977354
#
#
# ------------------------------------------------------------
#  to
# Páranção
# Eó de com doqvele a você, Porertoa denta
# cor a bem
# Eq er quaro e mai so que você mão az a um menterida arlacar não ao temevo
# E daa ira porar e ta fazer o que eu vom soso m vabe fica zinçao
# ----
# iter 65000, loss: 20.164793
#
#
# ------------------------------------------------------------
#   barande vomP
# Dosor angonde comação
#
# Bem vei que to fos a dolta deis, alazér
#
# à vou adboca
# De paz meu mrica, nasséar
# De vei leu vácerak
# E cantoda
# Hade eu am issou lou veme edo nhou, fico per do crrpar
# ----
# iter 66000, loss: 19.876688
#
#
# ------------------------------------------------------------
#  ou ce aissbor
# e telen
#
# Conta e tar:,
#
# Se plafuia
#
# Eulfpera lar re dei atar
# Aleu, pro perte e cheiço a minha m im mei poa não vem de propante ncomida
# Quendo mendo
# Nos ver ia porera
# Bem na buaçon, eu te
# ----
# iter 67000, loss: 20.338725
#
#
# ------------------------------------------------------------
#  tié fúira u menas vou tenta, poam r quente
# Mas a que hareo
#
# Sóo cesdo de vem você
# Ou, vode vam, nuaro de vetarse elê
# De, ela toracar
# Que eu quero e beijose bei queso queré é boiça deiva e que vos boca
# ----
# iter 68000, loss: 19.529601
#
#
# ------------------------------------------------------------
#  eras o a cueiço
# Mei fainhoradora prasom, eu asobeu te te come
# Nas am vima is era mosit
# Jinta
# Quara veu ma e é louco de me entiniré pe você
#
# De vase aslim, bei
# Quenço no aliza
#
# Lita
# E ter vouê sua
# Oisa
# ----
# iter 69000, loss: 20.389312
#
#
# ------------------------------------------------------------
#  que daina do faze do milha ue voite de paleré
# Se sem, ios em ima
# Não vou jo
# Eu aixarr
# Daisar
# Olha, ma masste çeo aU vege aro deico pesse peroreda deiscar elhan
# íogada
# E derutloder
# Aa eroliar e azero p
# ----
# iter 70000, loss: 19.421063
#
#
# ------------------------------------------------------------
#  ors
# Mum i ceme livar, vou seprosta, são com cara
# Mos gorte ro per porsir
# Sem só do meu tá mo cimto que eca
# Au sende mer
# á tão começar
# Nes ia es mevico tudo, eis é osovor
# Tur voi sa minabé porta
# Atod
# ----
# iter 71000, loss: 19.869175
#
#
# ------------------------------------------------------------
#  Che vou não seí
# Je quero a mim de enco deistér
# issborzes quentrdo que eu tão corer, uó sh urm poisse
# E cos oucas e contedidomande m a mister de taber
# Sa e cábelo
# Mas perfiça
#
# Não vou asse tar
#
# E meu t
# ----
# iter 72000, loss: 19.139412
#
#
# ------------------------------------------------------------
#  prasoltinção
# Te lam não casa é seu aim
# Sios ross o teugam vom de filaté
#
# Vaga cuncor dalho, fai tendo mais vachr, vique vacer mu amim
# Duixo jô bomasro emprema mou tasfaSmosta
# So guda sua joger você ma
# ----
# iter 73000, loss: 19.262488
#
#
# ------------------------------------------------------------
#  gar
#
# Ua du imastara que moma quentida do plimaRat
# oxa beplode,
# Atolo que te tercana de chvraic
# É oscom
# CêgNa faz nda uer
# Se inmo ndare, que Ouca malsa, eu jegontá s quem mei presto
# Tem a mepola de vou
# ----
# iter 74000, loss: 18.795215
#
#
# ------------------------------------------------------------
#  , uh, uh, uh
# Da da ema derale
# Eu te fazera
# Tanar soum jagar
#
# Tim
# Cocê quero cam io conçondo prazendo ou se entro aisba lida
#
# Pera io tem vafere
# A cinta (ndido
# Maser canco
# patar
# E am luchar am só eu pe
# ----
# iter 75000, loss: 19.250386
#
#
# ------------------------------------------------------------
#  é tin
# De de ela cemio bá a fazer que prinando tra meliz, de em lame dos menter
# Quendo bada me do eutaro, manco
# ponque éo que o hai você
# O que feprero a bolada, essa pendo que eu bente enpora que ficom
# ----
# iter 76000, loss: 18.589656
#
#
# ------------------------------------------------------------
#  e a quer pra mi, vai sele
# Eu previrad
# Que livar a mena
#
# Esso que eu não vou coma
# Eta da, uh, uh, uh, uh, ch, charer
# Deina ou tinho lo em axarerdepar foi mo sei mendo me pazesa
#
# ó que éu quende vorei s
# ----
# iter 77000, loss: 18.237359
#
#
# ------------------------------------------------------------
#   que eu voc ragas, quaro pro peivo que em ro temlida e lanhade a tera
# E  umaim
# Me anto em vocar m ustim
# Vintão
# Tá que eu pra, ro, não dá pade ém
#
# Eê vou a berate depoaz ra canto a veu te sor
# Jiros mei
# ----
# iter 78000, loss: 18.494071
#
#
# ------------------------------------------------------------
#  cpe gontado
# Vacê desda ertdo, cê)o s a em saim nhochr
# Não pou to mende, eó não tá maisssar
# Sa dinhere cobaissa, eis pra comação
#
# Empnque dereu vol foco vele ser em
# Eu só io tinho:,F
# O vicê pêrNão dens
# ----
# iter 79000, loss: 17.919030
#
#
# ------------------------------------------------------------
#  ra
# Aque é tonção
# Tá eucado tu fecar
# Bem na sua cara
#
# Eu peisquijo
# Já ea te voutjo me fegesavocê
# Nendo, lhhmisa
# E faz ido clago, contia do te eftero pra me ver tanta
# Aavendo que não no sliga me eu tô c
# ----
# iter 80000, loss: 18.714832
#
#
# ------------------------------------------------------------
#  m diz!r de lharara
#
# Eu vei a lim, é seucaro de nou não seu carter osgonçe dozer o tico de gozer
# Qua quer mais, levihe fez ladera, luque emponçanção
# QDeia!o
# Ta depliare
# Mentodo em focos subsa
#
# Se jeimi
# ----
# iter 81000, loss: 17.721556
#
#
# ------------------------------------------------------------
#  nar
#
# eu vou sofsirar padostadar
# Paidua
#
# Pravouha
# E adose eca mudi vem e nosse chrição
# Não a uande cheré sossio tão cos a mino me terendo mela tebolada fico
#
# E per oucha uss beija, sa bem você
#
# Esso mi
# ----
# iter 82000, loss: 18.390868
#
#
# ------------------------------------------------------------
#  ento menter
# Ptedona é padque, meix
#
# Mase, queravor terenos nosso dinga
# Não pou (nçir
# É e erela bem
#
# Tado aisírer, po vicê
# Me temer que é rá eusssiracandi bala
#
# Você perte ntoco, ele páo teua seisso os
# ----
# iter 83000, loss: 17.659690
# ------------------------------------------------------------
#   so seu lidar:
# Bó dit nluda, fago eu pmozerda me parara dei tão lá eutaro
# Messa  osso dezer que praseque enporquera
# Vois ero dogonha r ia eu to ocalia
# Eu ando tua care
# Mem veixqmelocê pesfimo que é te
# ----
# iter 84000, loss: 18.061368
#
#
# ------------------------------------------------------------
#  çar
# Não se prrepas boc, sfor
# Àão quero canto
# A friço suo perde atlina é polha me dase dera adorpraquenda mensem
# Tem jo eu cimevor rão pira é prontado
# Bem desma compando e aviratr
# Som iê pramai
#
# Eó de
# ----
# iter 85000, loss: 17.255976
#
#
# ------------------------------------------------------------
#  eu teu quero tesim bem, se bem não tide em gavaj iné meucar
# Quemou não feger canin
# Eu gontenvocaranto peu vis quela te re proder davass, eu tão quer na fuema em pissoi que vica meis é vor begorto or n
# ----
# iter 86000, loss: 17.832302
#
#
# ------------------------------------------------------------
#  ito com o querta eu sai
# Não fou tadinão meu você vai o pera ém doco me me ellepar
# Vai!
# Me taçona
#
# É mente conta bama m quar vou to loz asio que éuso o que eu nassofache lancanto sum você mim
# Qua de do
# ----
# iter 87000, loss: 17.278226
#
#
# ------------------------------------------------------------
#  veiso a meu
# A tôr fazNr a hemim
# E que eu mido o que tate der antor
# Dem iia ue fucor a meno adiser, er ouces contenir
#
# Seija cominos arar
#
# Deixa ele caraço dinga mpart, minhe co eua a a liva
# Não te fep
# ----
# iter 88000, loss: 16.926310
#
#
# ------------------------------------------------------------
#  ouco ja mu u mai
# Perpra à loua
# Endado e memofait, ela cervo te vecar tamco
# Mesando o que eu parais a der
# Su me aqfela frpra mor ique eu te semelem o rei, quer ima
# Mare
# Mosse alinda ma mais a amer
# Que
# ----
# iter 89000, loss: 17.149322
#
#
# ------------------------------------------------------------
#  s o sou, sóco pussbar elpas
# excendosfaito duqui, fim o cara, eu sénÉ é a bima perfoca qui éo ssor, aabe vencer
# Quar io tem deicor na veu cão poltar
# Não se acfize deixarelader
# Não que euche  chmiço do
# ----
# iter 90000, loss: 16.667079
#
#
# ------------------------------------------------------------
#  ais que ta vou da er develha
#
# Essa minta leu a aisé ngande do mucar vai bejo tá eu É arazendo
# Qua só dio
# Eu vou a uabra
# Eu ó nouquir
# Não pol ancina
#
# Vem, eu ficoca
# M suo que eu sou qua que e vou e cor
# ----
# iter 91000, loss: 17.436345
#
#
# ------------------------------------------------------------
#  ele sofrer
# Deixa ele saber
#
# Tempra
#
# Cho eu você mim,
# Vagu, foce po cummi, em veves mouco
# Me quere fimar
# E faz ndo fiê
# Eu fexto com vor aqui eu bib!e be jegura
# A diro, ola cario ve traro a falit
# de eu
# ----
# iter 92000, loss: 16.275570
#
#
# ------------------------------------------------------------
#  elha sibra
# Sei me seixa em intrar am nêm
# Te cê passa, lisej: rossa dima hegar
#
# E peroil queis de oche, boê
#
# ô Iá vo, ua saveis
# Be polhoci anto orablida ela mofaçasdo
# Eu veu te dendeda, pra me ver deit
# ----
# iter 93000, loss: 17.337762
#
#
# ------------------------------------------------------------
#  n
# E cer contando e cêpraido
# E pelouco que
# é a bia do mente jasso eu tão sente sen prrar
#
# E bão sho, lhouce em sem em quero em nho teu tãdr, me faz)i pra me vir são bempazs
# De teu não lem, faz o bogar
# ----
# iter 94000, loss: 16.520862
#
#
# ------------------------------------------------------------
#  zar ponto quero
# E vem vabo do ceradoser pous o quemes que tu vou fago dede tede am que éntomejohar na fazer
# Te lento bois que temis que to que campro mem vor rur raim
# Ele é tu lizar
# Tu mii a boita asm
# ----
# iter 95000, loss: 16.748168
#
#
# ------------------------------------------------------------
#   bem
# Só de olhar teus olim vei eu m imazem na sua cara
# Bem na sua cara
#
# Então
# Hore oraro te direr, conta poltar?
# Eu bobo que se lever, que que eu te momeis
# Mesta
#
# Pantanida co demanhadepanho
# Eu não to
# ----
# iter 96000, loss: 15.986060
#
#
# ------------------------------------------------------------
#   a heu tugar
# Eu tento dosinabera
# Abpesostir
#
# Entbrojo to tomansando mudia
# Eu vogera fiz não me pro vecê
#
# Lossa eu sóir, logere pela madose não minar
# Se delinde, babyi
# e em vicê vim, sia
# Ne nanorar
#
# Fa
# ----
# iter 97000, loss: 16.702837
#
#
# ------------------------------------------------------------
#  r vomê
# Eu sô quelo labaidode me sosta
# Faz ndidoa ma fnzendo me atilinar
# É que a vem intevadase Eu viparim
# Plaa assim
# Se tegente s vocêe e vequenda cocam bola
#
# Exeu lquer sas quero no não falete
# Rem o
# ----
# iter 98000, loss: 15.955499
#
#
# ------------------------------------------------------------
#  te
# Mas uda, lude que daich
# Nké io temino é lou, vager pre varçrdi
#
# Tuda pasem,, eina ola aa
# É pVagua, bragontr
# Que eu tevorar
# Dogondo eu sãi
# Sepor minha tode gar am prasar
# Não seu ladorar
# Eu tixá quer
# ----
# iter 99000, loss: 15.777048
