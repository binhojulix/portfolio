# %% [markdown]
# ## Tutorial on Backpropagation

# %%
# %matplotlib inline
import numpy as np
from pprint import pprint
from random import random
from matplotlib import pyplot as plt
plt.style.use('seaborn-pastel')

# %%
def actv_fn(x, fn='sigmoid', derivative=False):
    if not derivative:
        if fn == 'sigmoid': 
            return 1/(1+np.exp(-x))
        elif fn == 'relu':
            if x>0:
                return x
            else:
                return 0.01*x # leaky relu
        elif fn == 'tanh':
            return (2/(1+np.exp(-2*x)))-1
        else:
            return None
    else:
        if fn == 'sigmoid':
            # input x is value of sigmoid(x)
            return x*(1-x)
        elif fn == 'relu':
            # input x is value of relu(x) i.e x or 0.01x
            if x: 
                return 1
            return 0.01
        elif fn == 'tanh':
            # input x is value of tanh(x)
            return 1 - x*x
        else:
            return None
    
def error(y, yhat):
    return np.sum((np.subtract(yhat, y)**2)/2)

# %%
x = np.arange(-5, 5, 0.1)
fig = plt.figure(figsize=(24, 4))

y1 = [actv_fn(i, fn='sigmoid') for i in x]
ax1 = fig.add_subplot(131)
ax1.set_title('Sigmoid Function')
ax1.axvline(0, linewidth=1, color='black')
ax1.plot(x, y1, 'b-')

y2 = [actv_fn(i, fn='relu') for i in x]
ax2 = fig.add_subplot(132)
ax2.set_title('ReLU Function')
ax2.axvline(0, linewidth=1, color='black')
ax2.plot(x, y2, 'r-')

y3 = [actv_fn(i, fn='tanh') for i in x]
ax3 = fig.add_subplot(133)
ax3.set_title('TanH Function')
ax3.axvline(0, linewidth=1, color='black')
ax3.plot(x, y3, 'g-')

# %%
x = np.arange(-5, 5, 0.1)
fig = plt.figure(figsize=(24, 4))

y1 = [actv_fn(i, fn='sigmoid') for i in x]
y1 = [actv_fn(i, fn='sigmoid', derivative=True) for i in y1]
ax1 = fig.add_subplot(131)
ax1.set_title('Derivative of Sigmoid Function')
ax1.axvline(0, linewidth=1, color='black')
ax1.plot(x, y1, 'b-')

y2 = [actv_fn(i, fn='relu') for i in x]
y2 = [actv_fn(i, fn='relu', derivative=True) for i in y2]
ax2 = fig.add_subplot(132)
ax2.set_title('Derivative of ReLU Function')
ax2.axvline(0, linewidth=1, color='black')
ax2.plot(x, y2, 'r-')

y3 = [actv_fn(i, fn='tanh') for i in x]
y3 = [actv_fn(i, fn='tanh', derivative=True) for i in y3]
ax3 = fig.add_subplot(133)
ax3.set_title('Derivative of TanH Function')
ax3.axvline(0, linewidth=1, color='black')
ax3.plot(x, y3, 'g-')

# %%
class NeuralNet:
    def __init__(self, data, labels, weights, biases, function='sigmoid', learning_rate=0.05, tolerance=1e-5, max_iter=10000):
        self.x = data
        self.y = labels
        self.wts = weights
        self.b = biases
        self.fn = function
        self.eta = learning_rate
        self.tol = tolerance
        self.iterations = max_iter
        self.activations = []
        self.ERRORS = []
        self.show_params()
    
    def show_params(self):
        print ("Activation Function :", self.fn)
        print ("Learning Rate :", self.eta)
        print ("Tolerance :", self.tol)
        print ("Maximum Iterations :", self.iterations)
        print ("Number of layers :", self.wts.ndim)
        for i in range(self.wts.ndim):
            print ("----------------------")
            if i==0:
                print ("Input Layer :", self.wts.shape[i], "units")
            elif i==self.wts.ndim-1:
                print ("Output Layer :", self.wts.shape[i], "units")
                print ("----------------------")
                break
            else:
                print ("Layer", i, " (Hidden) :", self.wts.shape[i], "units")
            print ("Weights to next layer :")
            print(self.wts[i])
        print ("")
    
        
    def train(self):
        for i in range(self.iterations):
            if len(self.ERRORS)>1:
                err_delta = self.ERRORS[-2]-self.ERRORS[-1]
                #print err_delta
                if err_delta<self.tol:
                    print ("Converged at step", i-1, "with error", self.ERRORS[-1])
                    break
            self.frontprop()
            self.backprop()
    
    def frontprop(self, mode='train', pred_input=None):
        #print "Original weights"
        #pprint(self.wts)
        #print ""
        print ("Iteration", len(self.ERRORS))
        print ("Starting frontprop pass")
        if mode == 'train':
            fp_input=self.x
        elif mode == 'predict':
            assert(pred_input is not None)
            fp_input = pred_input
        else:
            return None
        
        for j in range(self.wts.shape[0]):
            #print "weight arr index :", j
            #print "input"
            if j == 0:
                inp = fp_input.copy()
                #try:
                #    np.dot(self.wts[j][0], inp)
                #except ValueError, e:
                #    print "INCOMPATIBLE DIMS"
                #print inp, "\n"
            else:
                inp = self.activations[-1]
                #print inp, "\n"
            outs = []
            for k in range(self.wts.shape[j]):
                #print "NET CALC : input", inp, ", weights", self.wts[j][k], ", biases", self.b[j]
                #print "W: len", len(self.wts), ":::",self.wts.shape,":::",self.wts[j].shape,":::",self.wts[j][k].shape, "X:", inp.shape, "b:", self.b.shape
                net = np.dot(self.wts[j][k], inp)+self.b[j]
                #print "NET :"
                #pprint(net)
                #print "OUT :"
                out = actv_fn(net, fn=self.fn)
                #pprint(out)
                outs.append(out)
                #print "----------"
            #print outs
            self.activations.append(np.array(outs))
            #print "----------------------------"
        final = self.activations[-1]
        final = np.array(final)
        total_error = 0.0
        for l in range(len(final)):
            #print l, final[l], self.y[l]
            err = error(final[l], self.y[l])
            total_error += err
        if mode == 'predict':
            return final
        print ("total error", total_error)
        self.ERRORS.append(total_error)
    
    def backprop(self):
        print ("Starting backprop pass")
        #print "Prev layers", len(self.activations)
        for j in range(self.wts.shape[0]):
            #print "Prev layers j", len(self.activations[j])
            for k in range(self.wts.shape[j]):
                p1 = self.activations[k][j]-self.y[j]
                #print "out_o - target", p1
                p2 = actv_fn(self.activations[k][j], fn=self.fn, derivative=True)
                #print "out_o*(1-out_o)", p2
                p3 = self.activations[k-1][j]
                #print "out_h", p3
                delta = -1*p1*p2*p3
                #print "delta", delta
                #print "change", self.eta*delta
                for l in range(len(self.wts[k][j])):
                    new_w = self.wts[k][j][l] + self.eta*delta # learning step
                    self.wts[k][j][l] = new_w
                #print ""
        #print "Modified Weights"
        #pprint(self.wts)
        print ("\n====================================================\n")
                
    def predict(self, input_x):
        return self.frontprop(mode='predict', pred_input=input_x)
    
    def plot_loss(self):
        plt.figure(figsize=(10,6))
        plt.xlim(0, 1.2*len(self.ERRORS))
        plt.xlabel('Iterations')
        plt.ylabel('Loss')
        plt.title('Training Loss over time')
        plt.plot([i for i in range(len(self.ERRORS))], self.ERRORS, 'b-')
        plt.show()

# %%
X = np.array([[0.05], [0.10]])
Y = np.array([[0.01], [0.99]])
W = np.array([
                [[0.15, 0.20],[0.25, 0.30]], #layer 0->1
                [[0.40, 0.45],[0.50, 0.55]]  #layer 1->2
               ])
B = np.array([[0.35], [0.6]])

NN = NeuralNet(X, Y, W, B, 'sigmoid', 0.5, 1e-5, 1000)
NN.train()
NN.plot_loss()
# Out:
# Activation Function : sigmoid
# Learning Rate : 0.5
# Tolerance : 1e-05
# Maximum Iterations : 1000
# Number of layers : 3
# ----------------------
# Input Layer : 2 units
# Weights to next layer :
# [[0.15 0.2 ]
#  [0.25 0.3 ]]
# ----------------------
# Layer 1  (Hidden) : 2 units
# Weights to next layer :
# [[0.4  0.45]
#  [0.5  0.55]]
# ----------------------
# Output Layer : 2 units
# ----------------------
#
# Iteration 0
# Starting frontprop pass
# total error 0.2983711087600027
# Starting backprop pass
#
# ====================================================
#
# Iteration 1
# Starting frontprop pass
# total error 0.29103631657807943
# Starting backprop pass
#
# ====================================================
#
# Iteration 2
# Starting frontprop pass
# total error 0.2836435570431649
# Starting backprop pass
#
# ====================================================
#
# Iteration 3
# Starting frontprop pass
# total error 0.27620148507047654
# Starting backprop pass
#
# ====================================================
#
# Iteration 4
# Starting frontprop pass
# total error 0.26871916564074066
# Starting backprop pass
#
# ====================================================
#
# Iteration 5
# Starting frontprop pass
# total error 0.26120603932022785
# Starting backprop pass
#
# ====================================================
#
# Iteration 6
# Starting frontprop pass
# total error 0.2536718835990579
# Starting backprop pass
#
# ====================================================
#
# Iteration 7
# Starting frontprop pass
# total error 0.24612677024848378
# Starting backprop pass
#
# ====================================================
#
# Iteration 8
# Starting frontprop pass
# total error 0.23858101896025732
# Starting backprop pass
#
# ====================================================
#
# Iteration 9
# Starting frontprop pass
# total error 0.23104514759284484
# Starting backprop pass
#
# ====================================================
#
# Iteration 10
# Starting frontprop pass
# total error 0.22352981940894426
# Starting backprop pass
#
# ====================================================
#
# Iteration 11
# Starting frontprop pass
# total error 0.21604578774515876
# Starting backprop pass
#
# ====================================================
#
# Iteration 12
# Starting frontprop pass
# total error 0.20860383860650525
# Starting backprop pass
#
# ====================================================
#
# Iteration 13
# Starting frontprop pass
# total error 0.2012147317244131
# Starting backprop pass
#
# ====================================================
#
# Iteration 14
# Starting frontprop pass
# total error 0.19388914065579907
# Starting backprop pass
#
# ====================================================
#
# Iteration 15
# Starting frontprop pass
# total error 0.18663759253159073
# Starting backprop pass
#
# ====================================================
#
# Iteration 16
# Starting frontprop pass
# total error 0.17947040808476794
# Starting backprop pass
#
# ====================================================
#
# Iteration 17
# Starting frontprop pass
# total error 0.17239764259981602
# Starting backprop pass
#
# ====================================================
#
# Iteration 18
# Starting frontprop pass
# total error 0.16542902842686036
# Starting backprop pass
#
# ====================================================
#
# Iteration 19
# Starting frontprop pass
# total error 0.15857391969433757
# Starting backprop pass
#
# ====================================================
#
# Iteration 20
# Starting frontprop pass
# total error 0.1518412398337552
# Starting backprop pass
#
# ====================================================
#
# Iteration 21
# Starting frontprop pass
# total error 0.14523943249905547
# Starting backprop pass
#
# ====================================================
#
# Iteration 22
# Starting frontprop pass
# total error 0.1387764164217489
# Starting backprop pass
#
# ====================================================
#
# Iteration 23
# Starting frontprop pass
# total error 0.13245954469201066
# Starting backprop pass
#
# ====================================================
#
# Iteration 24
# Starting frontprop pass
# total error 0.12629556889624033
# Starting backprop pass
#
# ====================================================
#
# Iteration 25
# Starting frontprop pass
# total error 0.12029060847433258
# Starting backprop pass
#
# ====================================================
#
# Iteration 26
# Starting frontprop pass
# total error 0.11445012558643076
# Starting backprop pass
#
# ====================================================
#
# Iteration 27
# Starting frontprop pass
# total error 0.10877890570072225
# Starting backprop pass
#
# ====================================================
#
# Iteration 28
# Starting frontprop pass
# total error 0.10328104403252139
# Starting backprop pass
#
# ====================================================
#
# Iteration 29
# Starting frontprop pass
# total error 0.09795993788213968
# Starting backprop pass
#
# ====================================================
#
# Iteration 30
# Starting frontprop pass
# total error 0.09281828483659241
# Starting backprop pass
#
# ====================================================
#
# Iteration 31
# Starting frontprop pass
# total error 0.08785808671972158
# Starting backprop pass
#
# ====================================================
#
# Iteration 32
# Starting frontprop pass
# total error 0.0830806590984495
# Starting backprop pass
#
# ====================================================
#
# Iteration 33
# Starting frontprop pass
# total error 0.07848664608111645
# Starting backprop pass
#
# ====================================================
#
# Iteration 34
# Starting frontprop pass
# total error 0.07407604007856101
# Starting backprop pass
#
# ====================================================
#
# Iteration 35
# Starting frontprop pass
# total error 0.06984820614091569
# Starting backprop pass
#
# ====================================================
#
# Iteration 36
# Starting frontprop pass
# total error 0.0658019104339741
# Starting backprop pass
#
# ====================================================
#
# Iteration 37
# Starting frontprop pass
# total error 0.061935352379124724
# Starting backprop pass
#
# ====================================================
#
# Iteration 38
# Starting frontprop pass
# total error 0.058246199950708205
# Starting backprop pass
#
# ====================================================
#
# Iteration 39
# Starting frontprop pass
# total error 0.054731627604429074
# Starting backprop pass
#
# ====================================================
#
# Iteration 40
# Starting frontprop pass
# total error 0.051388356300099775
# Starting backprop pass
#
# ====================================================
#
# Iteration 41
# Starting frontprop pass
# total error 0.04821269508122312
# Starting backprop pass
#
# ====================================================
#
# Iteration 42
# Starting frontprop pass
# total error 0.04520058368223698
# Starting backprop pass
#
# ====================================================
#
# Iteration 43
# Starting frontprop pass
# total error 0.04234763565095824
# Starting backprop pass
#
# ====================================================
#
# Iteration 44
# Starting frontprop pass
# total error 0.03964918149802501
# Starting backprop pass
#
# ====================================================
#
# Iteration 45
# Starting frontprop pass
# total error 0.037100311415973475
# Starting backprop pass
#
# ====================================================
#
# Iteration 46
# Starting frontprop pass
# total error 0.03469591714693167
# Starting backprop pass
#
# ====================================================
#
# Iteration 47
# Starting frontprop pass
# total error 0.032430732618651335
# Starting backprop pass
#
# ====================================================
#
# Iteration 48
# Starting frontprop pass
# total error 0.030299373012584487
# Starting backprop pass
#
# ====================================================
#
# Iteration 49
# Starting frontprop pass
# total error 0.028296371973831527
# Starting backprop pass
#
# ====================================================
#
# Iteration 50
# Starting frontprop pass
# total error 0.026416216719942827
# Starting backprop pass
#
# ====================================================
#
# Iteration 51
# Starting frontprop pass
# total error 0.024653380852748298
# Starting backprop pass
#
# ====================================================
#
# Iteration 52
# Starting frontprop pass
# total error 0.023002354723684393
# Starting backprop pass
#
# ====================================================
#
# Iteration 53
# Starting frontprop pass
# total error 0.021457673247674267
# Starting backprop pass
#
# ====================================================
#
# Iteration 54
# Starting frontprop pass
# total error 0.0200139411027928
# Starting backprop pass
#
# ====================================================
#
# Iteration 55
# Starting frontprop pass
# total error 0.018665855292140245
# Starting backprop pass
#
# ====================================================
#
# Iteration 56
# Starting frontprop pass
# total error 0.017408225080106823
# Starting backprop pass
#
# ====================================================
#
# Iteration 57
# Starting frontprop pass
# total error 0.016235989347215655
# Starting backprop pass
#
# ====================================================
#
# Iteration 58
# Starting frontprop pass
# total error 0.01514423143577628
# Starting backprop pass
#
# ====================================================
#
# Iteration 59
# Starting frontprop pass
# total error 0.014128191582573137
# Starting backprop pass
#
# ====================================================
#
# Iteration 60
# Starting frontprop pass
# total error 0.01318327705476227
# Starting backprop pass
#
# ====================================================
#
# Iteration 61
# Starting frontprop pass
# total error 0.012305070121145144
# Starting backprop pass
#
# ====================================================
#
# Iteration 62
# Starting frontprop pass
# total error 0.011489334003204635
# Starting backprop pass
#
# ====================================================
#
# Iteration 63
# Starting frontprop pass
# total error 0.010732016958950492
# Starting backprop pass
#
# ====================================================
#
# Iteration 64
# Starting frontprop pass
# total error 0.010029254658007929
# Starting backprop pass
#
# ====================================================
#
# Iteration 65
# Starting frontprop pass
# total error 0.009377371008803467
# Starting backprop pass
#
# ====================================================
#
# Iteration 66
# Starting frontprop pass
# total error 0.00877287759848641
# Starting backprop pass
#
# ====================================================
#
# Iteration 67
# Starting frontprop pass
# total error 0.008212471903716847
# Starting backprop pass
#
# ====================================================
#
# Iteration 68
# Starting frontprop pass
# total error 0.007693034425990937
# Starting backprop pass
#
# ====================================================
#
# Iteration 69
# Starting frontprop pass
# total error 0.007211624899099902
# Starting backprop pass
#
# ====================================================
#
# Iteration 70
# Starting frontprop pass
# total error 0.006765477708947456
# Starting backprop pass
#
# ====================================================
#
# Iteration 71
# Starting frontprop pass
# total error 0.006351996657584742
# Starting backprop pass
#
# ====================================================
#
# Iteration 72
# Starting frontprop pass
# total error 0.0059687491942373395
# Starting backprop pass
#
# ====================================================
#
# Iteration 73
# Starting frontprop pass
# total error 0.005613460226546218
# Starting backprop pass
#
# ====================================================
#
# Iteration 74
# Starting frontprop pass
# total error 0.005284005615446468
# Starting backprop pass
#
# ====================================================
#
# Iteration 75
# Starting frontprop pass
# total error 0.004978405447256439
# Starting backprop pass
#
# ====================================================
#
# Iteration 76
# Starting frontprop pass
# total error 0.00469481716681179
# Starting backprop pass
#
# ====================================================
#
# Iteration 77
# Starting frontprop pass
# total error 0.004431528645991443
# Starting backprop pass
#
# ====================================================
#
# Iteration 78
# Starting frontprop pass
# total error 0.004186951252855724
# Starting backprop pass
#
# ====================================================
#
# Iteration 79
# Starting frontprop pass
# total error 0.0039596129779410055
# Starting backprop pass
#
# ====================================================
#
# Iteration 80
# Starting frontprop pass
# total error 0.0037481516660927967
# Starting backprop pass
#
# ====================================================
#
# Iteration 81
# Starting frontprop pass
# total error 0.0035513083946180565
# Starting backprop pass
#
# ====================================================
#
# Iteration 82
# Starting frontprop pass
# total error 0.0033679210315253
# Starting backprop pass
#
# ====================================================
#
# Iteration 83
# Starting frontprop pass
# total error 0.0031969180012110993
# Starting backprop pass
#
# ====================================================
#
# Iteration 84
# Starting frontprop pass
# total error 0.0030373122791453907
# Starting backprop pass
#
# ====================================================
#
# Iteration 85
# Starting frontprop pass
# total error 0.0028881956318948816
# Starting backprop pass
#
# ====================================================
#
# Iteration 86
# Starting frontprop pass
# total error 0.0027487331141868208
# Starting backprop pass
#
# ====================================================
#
# Iteration 87
# Starting frontprop pass
# total error 0.0026181578306286087
# Starting backprop pass
#
# ====================================================
#
# Iteration 88
# Starting frontprop pass
# total error 0.0024957659661328643
# Starting backprop pass
#
# ====================================================
#
# Iteration 89
# Starting frontprop pass
# total error 0.0023809120860195645
# Starting backprop pass
#
# ====================================================
#
# Iteration 90
# Starting frontprop pass
# total error 0.002273004704140284
# Starting backprop pass
#
# ====================================================
#
# Iteration 91
# Starting frontprop pass
# total error 0.0021715021151582493
# Starting backprop pass
#
# ====================================================
#
# Iteration 92
# Starting frontprop pass
# total error 0.0020759084852847946
# Starting backprop pass
#
# ====================================================
#
# Iteration 93
# Starting frontprop pass
# total error 0.0019857701942805426
# Starting backprop pass
#
# ====================================================
#
# Iteration 94
# Starting frontprop pass
# total error 0.001900672420342609
# Starting backprop pass
#
# ====================================================
#
# Iteration 95
# Starting frontprop pass
# total error 0.0018202359585845205
# Starting backprop pass
#
# ====================================================
#
# Iteration 96
# Starting frontprop pass
# total error 0.0017441142631380287
# Starting backprop pass
#
# ====================================================
#
# Iteration 97
# Starting frontprop pass
# total error 0.001671990702438682
# Starting backprop pass
#
# ====================================================
#
# Iteration 98
# Starting frontprop pass
# total error 0.0016035760169684048
# Starting backprop pass
#
# ====================================================
#
# Iteration 99
# Starting frontprop pass
# total error 0.0015386059685951275
# Starting backprop pass
#
# ====================================================
#
# Iteration 100
# Starting frontprop pass
# total error 0.0014768391706460905
# Starting backprop pass
#
# ====================================================
#
# Iteration 101
# Starting frontprop pass
# total error 0.001418055087957731
# Starting backprop pass
#
# ====================================================
#
# Iteration 102
# Starting frontprop pass
# total error 0.0013620521963410113
# Starting backprop pass
#
# ====================================================
#
# Iteration 103
# Starting frontprop pass
# total error 0.0013086462911703135
# Starting backprop pass
#
# ====================================================
#
# Iteration 104
# Starting frontprop pass
# total error 0.00125766893513021
# Starting backprop pass
#
# ====================================================
#
# Iteration 105
# Starting frontprop pass
# total error 0.0012089660355263396
# Starting backprop pass
#
# ====================================================
#
# Iteration 106
# Starting frontprop pass
# total error 0.001162396541970199
# Starting backprop pass
#
# ====================================================
#
# Iteration 107
# Starting frontprop pass
# total error 0.0011178312556752075
# Starting backprop pass
#
# ====================================================
#
# Iteration 108
# Starting frontprop pass
# total error 0.0010751517420428756
# Starting backprop pass
#
# ====================================================
#
# Iteration 109
# Starting frontprop pass
# total error 0.001034249338666892
# Starting backprop pass
#
# ====================================================
#
# Iteration 110
# Starting frontprop pass
# total error 0.0009950242513329672
# Starting backprop pass
#
# ====================================================
#
# Iteration 111
# Starting frontprop pass
# total error 0.0009573847310387573
# Starting backprop pass
#
# ====================================================
#
# Iteration 112
# Starting frontprop pass
# total error 0.0009212463254963342
# Starting backprop pass
#
# ====================================================
#
# Iteration 113
# Starting frontprop pass
# total error 0.0008865311990073226
# Starting backprop pass
#
# ====================================================
#
# Iteration 114
# Starting frontprop pass
# total error 0.0008531675150139879
# Starting backprop pass
#
# ====================================================
#
# Iteration 115
# Starting frontprop pass
# total error 0.0008210888760276217
# Starting backprop pass
#
# ====================================================
#
# Iteration 116
# Starting frontprop pass
# total error 0.0007902338160164549
# Starting backprop pass
#
# ====================================================
#
# Iteration 117
# Starting frontprop pass
# total error 0.000760545340697604
# Starting backprop pass
#
# ====================================================
#
# Iteration 118
# Starting frontprop pass
# total error 0.000731970511521923
# Starting backprop pass
#
# ====================================================
#
# Iteration 119
# Starting frontprop pass
# total error 0.0007044600694654714
# Starting backprop pass
#
# ====================================================
#
# Iteration 120
# Starting frontprop pass
# total error 0.0006779680950472685
# Starting backprop pass
#
# ====================================================
#
# Iteration 121
# Starting frontprop pass
# total error 0.0006524517012803214
# Starting backprop pass
#
# ====================================================
#
# Iteration 122
# Starting frontprop pass
# total error 0.0006278707565318033
# Starting backprop pass
#
# ====================================================
#
# Iteration 123
# Starting frontprop pass
# total error 0.0006041876345188529
# Starting backprop pass
#
# ====================================================
#
# Iteration 124
# Starting frontprop pass
# total error 0.0005813669889004271
# Starting backprop pass
#
# ====================================================
#
# Iteration 125
# Starting frontprop pass
# total error 0.0005593755501423947
# Starting backprop pass
#
# ====================================================
#
# Iteration 126
# Starting frontprop pass
# total error 0.0005381819425342432
# Starting backprop pass
#
# ====================================================
#
# Iteration 127
# Starting frontprop pass
# total error 0.0005177565194219183
# Starting backprop pass
#
# ====================================================
#
# Iteration 128
# Starting frontprop pass
# total error 0.00049807121489299
# Starting backprop pass
#
# ====================================================
#
# Iteration 129
# Starting frontprop pass
# total error 0.0004790994103087969
# Starting backprop pass
#
# ====================================================
#
# Iteration 130
# Starting frontprop pass
# total error 0.0004608158142238915
# Starting backprop pass
#
# ====================================================
#
# Iteration 131
# Starting frontprop pass
# total error 0.00044319635436703336
# Starting backprop pass
#
# ====================================================
#
# Iteration 132
# Starting frontprop pass
# total error 0.0004262180804806401
# Starting backprop pass
#
# ====================================================
#
# Iteration 133
# Starting frontprop pass
# total error 0.0004098590769284204
# Starting backprop pass
#
# ====================================================
#
# Iteration 134
# Starting frontprop pass
# total error 0.0003940983840834709
# Starting backprop pass
#
# ====================================================
#
# Iteration 135
# Starting frontprop pass
# total error 0.000378915927603509
# Starting backprop pass
#
# ====================================================
#
# Iteration 136
# Starting frontprop pass
# total error 0.0003642924547855528
# Starting backprop pass
#
# ====================================================
#
# Iteration 137
# Starting frontprop pass
# total error 0.00035020947727063494
# Starting backprop pass
#
# ====================================================
#
# Iteration 138
# Starting frontprop pass
# total error 0.00033664921944045974
# Starting backprop pass
#
# ====================================================
#
# Iteration 139
# Starting frontprop pass
# total error 0.0003235945719125416
# Starting backprop pass
#
# ====================================================
#
# Iteration 140
# Starting frontprop pass
# total error 0.000311029049599484
# Starting backprop pass
#
# ====================================================
#
# Iteration 141
# Starting frontprop pass
# total error 0.0002989367538511793
# Starting backprop pass
#
# ====================================================
#
# Iteration 142
# Starting frontprop pass
# total error 0.00028730233824748283
# Starting backprop pass
#
# ====================================================
#
# Iteration 143
# Starting frontprop pass
# total error 0.0002761109776526024
# Starting backprop pass
#
# ====================================================
#
# Iteration 144
# Starting frontprop pass
# total error 0.00026534834018226197
# Starting backprop pass
#
# ====================================================
#
# Iteration 145
# Starting frontprop pass
# total error 0.0002550005617705739
# Starting backprop pass
#
# ====================================================
#
# Iteration 146
# Starting frontprop pass
# total error 0.0002450542230561913
# Starting backprop pass
#
# ====================================================
#
# Converged at step 146 with error 0.0002450542230561913

# %%
print (NN.activations[-1])
# Out:
# [[0.00125097]
#  [0.96966375]]
