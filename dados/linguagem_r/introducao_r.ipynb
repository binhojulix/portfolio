# %%
# Dados daspessoas
idade=c(24,48,32,65,38,56,74,19,29,22)
peso=c(80,67,49,55,89,72,45,88,56,74)
altura=c(180,165,162,175,172,165,168,185,172,168)
sexo=c('M','F','M','F','M','F','M','F','M','F')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13008/1731312798.py in <module>
#       1 # Dados daspessoas
# ----> 2 idade=c(24,48,32,65,38,56,74,19,29,22)
#       3 peso=c(80,67,49,55,89,72,45,88,56,74)
#       4 altura=c(180,165,162,175,172,165,168,185,172,168)
#       5 sexo=c('M','F','M','F','M','F','M','F','M','F')
#
# NameError: name 'c' is not defined
